# %%
import import_ipynb

import numpy as np
import pandas as pd
import time as timer
import matplotlib.pyplot as plt

# %%
from mondrian_graph import *
from mondrian_functions  import *

# %%
#Get data from CSV
file_name = 'dataset/data_{}k.csv'

sizes = [1, 2 , 5, 10, 20 , 30]
quasi_identifiers = ["age","zip_code"]
ks = [10,5]

results = []

# %% [markdown]
# # Mondrian flow

# %%
 

for size in sizes:
    for k in ks:
        file = file_name.format(size)
        print(file)
        data = pd.read_csv(file)

        dataset_size = data.shape[0]
        print('Iterating dataset of ', dataset_size)

        qi_df = pd.DataFrame(data, columns = quasi_identifiers)

        start_time = timer.time()

        # K no of rows same in the qi_data
        anonymized_data = recursive_iteration(qi_df, k)

        end_time = timer.time()
        time_taken = end_time - start_time
        results.append([dataset_size, time_taken,k])

        print('Time takes: ', time_taken)

        print('Anonymized Data: ', anonymized_data)
        print('---------------------------------')
# Out:
# dataset/data_1k.csv
# Iterating dataset of  1000
# Time takes:  0.11927676200866699
# Anonymized Data:         age     zip_code
# 0    25-43  61854-67735
# 1    25-43  61854-67735
# 2    25-43  61854-67735
# 3    25-43  61854-67735
# 4    25-43  61854-67735
# ..     ...          ...
# 995  26-44  61029-68106
# 996  26-44  61029-68106
# 997  26-44  61029-68106
# 998  26-44  61029-68106
# 999  26-44  61029-68106
#
# [1000 rows x 2 columns]
# ---------------------------------
# dataset/data_1k.csv
# Iterating dataset of  1000
# Time takes:  0.1848597526550293
# Anonymized Data:         age     zip_code
# 0    25-39  62565-67735
# 1    25-39  62565-67735
# 2    25-39  62565-67735
# 3    25-39  62565-67735
# 4    31-43  61854-67235
# ..     ...          ...
# 995  26-44  61029-68106
# 996  26-44  61029-68106
# 997  29-43  63613-66608
# 998  29-43  63613-66608
# 999  29-43  63613-66608
#
# [1000 rows x 2 columns]
# ---------------------------------
# dataset/data_2k.csv
# Iterating dataset of  1999
# Time takes:  0.17618918418884277
# Anonymized Data:          age     zip_code
# 0     25-43  61854-67735
# 1     25-43  61854-67735
# 2     25-43  61854-67735
# 3     25-43  61854-67735
# 4     25-43  61854-67735
# ...     ...          ...
# 1994  24-44  61478-67603
# 1995  24-44  61478-67603
# 1996  24-44  61478-67603
# 1997  24-44  61478-67603
# 1998  24-44  61478-67603
#
# [1999 rows x 2 columns]
# ---------------------------------
# dataset/data_2k.csv
# Iterating dataset of  1999
# Time takes:  0.4485907554626465
# Anonymized Data:          age     zip_code
# 0     25-39  62565-67735
# 1     25-39  62565-67735
# 2     25-39  62565-67735
# 3     25-39  62565-67735
# 4     31-43  61854-67235
# ...     ...          ...
# 1994  24-38  62250-67603
# 1995  24-38  62250-67603
# 1996  25-44  61478-66892
# 1997  25-44  61478-66892
# 1998  25-44  61478-66892
#
# [1999 rows x 2 columns]
# ---------------------------------
# dataset/data_5k.csv
# Iterating dataset of  4999
# Time takes:  0.4409935474395752
# Anonymized Data:          age     zip_code
# 0     25-42  61417-68857
# 1     25-42  61417-68857
# 2     25-42  61417-68857
# 3     25-42  61417-68857
# 4     25-42  61417-68857
# ...     ...          ...
# 4994  25-44  61221-67881
# 4995  25-44  61221-67881
# 4996  25-44  61221-67881
# 4997  25-44  61221-67881
# 4998  25-44  61221-67881
#
# [4999 rows x 2 columns]
# ---------------------------------
# dataset/data_5k.csv
# Iterating dataset of  4999
# Time takes:  0.7809538841247559
# Anonymized Data:          age     zip_code
# 0     27-41  61417-67049
# 1     27-41  61417-67049
# 2     27-41  61417-67049
# 3     27-41  61417-67049
# 4     27-41  61417-67049
# ...     ...          ...
# 4994  25-44  61221-66602
# 4995  25-32  62303-67881
# 4996  25-32  62303-67881
# 4997  25-32  62303-67881
# 4998  25-32  62303-67881
#
# [4999 rows x 2 columns]
# ---------------------------------
# dataset/data_10k.csv
# Iterating dataset of  9999
# Time takes:  0.7833981513977051
# Anonymized Data:          age     zip_code
# 0     25-43  61713-67735
# 1     25-43  61713-67735
# 2     25-43  61713-67735
# 3     25-43  61713-67735
# 4     25-43  61713-67735
# ...     ...          ...
# 9994  27-42  61010-68659
# 9995  27-42  61010-68659
# 9996  27-42  61010-68659
# 9997  27-42  61010-68659
# 9998  27-42  61010-68659
#
# [9999 rows x 2 columns]
# ---------------------------------
# dataset/data_10k.csv
# Iterating dataset of  9999
# Time takes:  1.453057050704956
# Anonymized Data:          age     zip_code
# 0     25-43  62565-67735
# 1     25-43  62565-67735
# 2     25-43  62565-67735
# 3     25-43  62565-67735
# 4     25-43  62565-67735
# ...     ...          ...
# 9994  31-42  61010-68598
# 9995  27-42  63114-68659
# 9996  27-42  63114-68659
# 9997  27-42  63114-68659
# 9998  27-42  63114-68659
#
# [9999 rows x 2 columns]
# ---------------------------------
# dataset/data_20k.csv
# Iterating dataset of  20000
# Time takes:  2.020085573196411
# Anonymized Data:           age     zip_code
# 0      25-43  61713-67735
# 1      25-43  61713-67735
# 2      25-43  61713-67735
# 3      25-43  61713-67735
# 4      25-43  61713-67735
# ...      ...          ...
# 19995  27-42  61010-68659
# 19996  27-42  61010-68659
# 19997  27-42  61010-68659
# 19998  27-42  61010-68659
# 19999  27-42  61010-68659
#
# [20000 rows x 2 columns]
# ---------------------------------
# dataset/data_20k.csv
# Iterating dataset of  20000
# Time takes:  3.606905937194824
# Anonymized Data:           age     zip_code
# 0      25-43  62565-67735
# 1      25-43  62565-67735
# 2      25-43  62565-67735
# 3      25-43  62565-67735
# 4      25-43  62565-67735
# ...      ...          ...
# 19995  27-42  61010-68659
# 19996  30-42  63114-66972
# 19997  30-42  63114-66972
# 19998  30-42  63114-66972
# 19999  30-42  63114-66972
#
# [20000 rows x 2 columns]
# ---------------------------------
# dataset/data_30k.csv
# Iterating dataset of  30000
# Time takes:  3.2743780612945557
# Anonymized Data:           age     zip_code
# 0      25-43  61854-67735
# 1      25-43  61854-67735
# 2      25-43  61854-67735
# 3      25-43  61854-67735
# 4      25-43  61854-67735
# ...      ...          ...
# 29995  27-42  61010-68659
# 29996  27-42  61010-68659
# 29997  27-42  61010-68659
# 29998  27-42  61010-68659
# 29999  27-42  61010-68659
#
# [30000 rows x 2 columns]
# ---------------------------------
# dataset/data_30k.csv
# Iterating dataset of  30000
# Time takes:  6.03888726234436
# Anonymized Data:           age     zip_code
# 0      25-39  62565-67735
# 1      25-39  62565-67735
# 2      25-39  62565-67735
# 3      25-39  62565-67735
# 4      31-43  61854-67235
# ...      ...          ...
# 29995  27-42  61010-68659
# 29996  27-42  61010-68659
# 29997  28-42  61203-66282
# 29998  28-42  61203-66282
# 29999  28-42  61203-66282
#
# [30000 rows x 2 columns]
# ---------------------------------

# %%
size = np.array(results)[:,0]
time = np.array(results)[:,1]
k = np.array(results)[:,2]

column_values = ['size', 'time', 'k']
df = pd.DataFrame(data = results, 
                  columns = column_values)
# Out:
#      size      time   k
# 0    1000  0.119277  10
# 2    1999  0.176189  10
# 4    4999  0.440994  10
# 6    9999  0.783398  10
# 8   20000  2.020086  10
# 10  30000  3.274378  10

# %%
plt.figure()
plt.ylabel('Time (Sec)', fontsize=18)
plt.xlabel('No of rows', fontsize=16)

for k in ks:
    plt.plot(
        df[df['k']==k]['size'], 
        df[df['k']==k]['time'], 
        label=k)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['size'], df['time'],
           linewidths=1, alpha=.7,
           edgecolor='k',
           s = 200,
           c=df['k'])
